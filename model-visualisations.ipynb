# %%
# Imports, as always.
import torch
from torch.utils.data import DataLoader

from models.hopfield_restoration import build_hopfield_restoration_block
from models.image_segmentation import SegmentationModel
from data_handling import ISICDataset

from torchview import draw_graph

# Ignore warnings.
import warnings
warnings.filterwarnings('ignore')
# Out:
# /home/benprie/miniconda3/envs/mlp-project-wsl/lib/python3.8/site-packages/torch/__init__.py:614: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:451.)
#   _C._set_default_tensor_type(t)

# %%
model = build_hopfield_restoration_block(image_size=128, patch_size=4, channels=3, embed_dim=768, stored_patterns=2**14)

dummy_input = torch.randn(1, 3, 128, 128)
model_graph = draw_graph(model, input_data=dummy_input)
model_graph.visual_graph
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/miniconda3/envs/mlp-project-wsl/lib/python3.8/site-packages/graphviz/backend/execute.py:79, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      78         kwargs['stdout'] = kwargs['stderr'] = subprocess.PIPE
# ---> 79     proc = _run_input_lines(cmd, input_lines, kwargs=kwargs)
#      80 else:
#
# File ~/miniconda3/envs/mlp-project-wsl/lib/python3.8/site-packages/graphviz/backend/execute.py:99, in _run_input_lines(cmd, input_lines, kwargs)
#      98 def _run_input_lines(cmd, input_lines, *, kwargs):
# ---> 99     popen = subprocess.Popen(cmd, stdin=subprocess.PIPE, **kwargs)
#     101     stdin_write = popen.stdin.write
#
# ...
